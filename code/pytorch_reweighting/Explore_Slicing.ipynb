# %%
from model import *
from data_loader import *
from reweighting import *

import matplotlib
matplotlib.rcParams.update({'errorbar.capsize': 5})

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Test for multiclass

# %%
platform = Reweighting()

# %%
platform.setup_data(dataset_name='mnist', classes=[1,2,3,4], weights=[0.4,0.4,0.1,0.1], n_vals_per_class=[5,5,5,5], batch_size=100)
# Out:
# ...
# Getting data loader for mnist
# Loading train data
# Gathered 5000 train samples
# Gathered 20 validation samples
# Loading test data
# Gathered 4159 test samples
# Data loader initialized
# ...

# %%
platform.setup_model()
# Out:
# ...
# Setting up model for dataset mnist
# Model setup finished
# ...

# %%
platform.train_reweighted(num_iter=1000, learning_rate=0.001)
# Out:
#  90%|███████████████████████████████████████████████████████████████████████▏       | 901/1000 [11:15<03:10,  1.92s/it]
#
#
#
#
#
#
#
#
#  90%|███████████████████████████████████████████████████████████████████████▎       | 902/1000 [11:15<02:19,  1.42s/it]
#
#
#
#
#
#
#
#
#  90%|███████████████████████████████████████████████████████████████████████▎       | 903/1000 [11:15<01:52,  1.16s/it]
#
#
#
#
#
#
#
#
#  90%|███████████████████████████████████████████████████████████████████████▍       | 904/1000 [11:16<01:26,  1.11it/s]
#
#
#
#
#
#
#
#
#  90%|███████████████████████████████████████████████████████████████████████▍       | 905/1000 [11:16<01:09,  1.37it/s]
#
#
#
#
#
#
#
#
#  91%|███████████████████████████████████████████████████████████████████████▌       | 906/1000 [11:17<01:01,  1.52it/s]
#
#
#
#
#
#
#
#
#  91%|███████████████████████████████████████████████████████████████████████▋       | 907/1000 [11:17<00:54,  1.71it/s]
#
#
#
#
#
#
#
#
# ...

# %%
platform.train(num_iter=1000, learning_rate=0.001)
# Out:
#  50%|███████████████████████████████████████                                       | 1001/2000 [01:45<06:13,  2.68it/s]
#
#
#
#
#
#
#
#  50%|███████████████████████████████████████                                       | 1003/2000 [01:45<04:41,  3.54it/s]
#
#
#
#
#
#
#
#  50%|███████████████████████████████████████▏                                      | 1005/2000 [01:45<03:47,  4.38it/s]
#
#
#
#
#
#
#
#  50%|███████████████████████████████████████▎                                      | 1007/2000 [01:45<03:04,  5.37it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-3ad99c777808> in <module>
# ----> 1 platform.train(num_iter=2000, learning_rate=0.001)
#
# ~\Documents\Stanford\Research\Re\Reweighting\code\pytorch_reweighting\reweighting.py in train(self, num_iter, learning_rate)
#     116             y_train = to_var(y_train, requires_grad=False)
# ...

# %% [markdown]
# ### Slicing

# %% [markdown]
# #### 3 total classes, only 2 classes in validation

# %% [markdown]
# Try to see the performance when we have 3 classes in data, but we only have 2 classes in validation. Assume that 3 classes in training data are equally distributed
#
# It seems like we perform poorly compared to regular training

# %%
platform = Reweighting()

# %%
platform.setup_data(dataset_name='mnist', classes=[1,2,3], weights=[1,1,1], n_vals_per_class=[0,5,5], batch_size=100)
# Out:
# ...
# Getting data loader for mnist
# Loading train data
# Gathered 4998 train samples
# Gathered 10 validation samples
# Loading test data
# Gathered 3177 test samples
# Data loader initialized
# ...

# %%
platform.setup_model()
platform.train_reweighted(num_iter=1000, learning_rate=0.01)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [03:54<00:00,  5.10it/s]
# train_reweighted finished
# ...
# (Actual Ind, Predicted Ind): count
# Counter({(1, 1): 1013, (2, 2): 997, (0, 2): 584, (0, 0): 527, (0, 1): 24, (1, 2): 19, (2, 1): 13})

# %%
platform.train(num_iter=1000, learning_rate=0.01)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:14<00:00, 13.34it/s]
# ...

# %% [markdown]
# #### 3 total classes, 2 classes weighted heavily in validation

# %%
Try to see the performance when we have 3 classes in data, but we only have 2 classes in validation. Assume that 3 classes in training data are equally distributed

It seems like we perform poorly compared to regular training

# %%
platform = Reweighting()
platform.setup_data(dataset_name='mnist', classes=[1,2,3], weights=[1,1,1], n_vals_per_class=[1,5,5], batch_size=100)
platform.setup_model()
# Out:
# ...
# Getting data loader for mnist
# Loading train data
# Gathered 4998 train samples
# Gathered 11 validation samples
# Loading test data
# Gathered 3177 test samples
# Data loader initialized
# ...
# Setting up model for dataset mnist
# Model setup finished
# ...

# %%
platform.train_reweighted(num_iter=1000, learning_rate=0.01)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:18<00:00,  5.30it/s]
# train_reweighted finished
# ...
# (Actual Ind, Predicted Ind): count
# Counter({(0, 0): 1056, (2, 2): 1010, (1, 1): 846, (1, 2): 170, (0, 2): 79, (1, 0): 16})

# %% [markdown]
# #### To actually see performance boost in models, let's use CIFAR, which has lower accuracy
#
# It seems like we cannot naively just change the number of valid samples and hope for better results for those

# %%
platform = Reweighting()
platform.setup_data(dataset_name='cifar', classes=[1,2,3], weights=[1,1,1], n_vals_per_class=[0,5,5], batch_size=100)
platform.setup_model()
# Out:
# ...
# Getting data loader for cifar
# Loading train data
# Files already downloaded and verified
# Gathered 4998 train samples
# Gathered 10 validation samples
# Loading test data
# Files already downloaded and verified
# Gathered 3000 test samples
# Data loader initialized
# ...
# Setting up model for dataset cifar
# Model setup finished
# ...

# %%
platform.train_reweighted(num_iter=1500, learning_rate=0.01)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1500/1500 [05:09<00:00,  4.31it/s]
# train_reweighted finished
# ...
# (Actual, Predicted): count
# Counter({(2, 2): 808, (1, 2): 583, (3, 3): 517, (3, 2): 483, (1, 3): 417, (2, 3): 192})

# %%
platform = Reweighting()
platform.setup_data(dataset_name='cifar', classes=[1,2,3], weights=[1,1,1], n_vals_per_class=[3,5,5], batch_size=100)
platform.setup_model()
# Out:
# ...
# Getting data loader for cifar
# Loading train data
# Files already downloaded and verified
# Gathered 4998 train samples
# Gathered 13 validation samples
# Loading test data
# Files already downloaded and verified
# Gathered 3000 test samples
# Data loader initialized
# ...
# Setting up model for dataset cifar
# Model setup finished
# ...

# %%
platform.train_reweighted(num_iter=1500, learning_rate=0.01)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1500/1500 [07:23<00:00,  4.33it/s]
# train_reweighted finished
# ...
# (Actual, Predicted): count
# Counter({(1, 1): 910, (3, 3): 578, (2, 2): 442, (2, 3): 371, (3, 2): 255, (2, 1): 187, (3, 1): 167, (1, 3): 58, (1, 2): 32})

# %%
platform.train(num_iter=1500, learning_rate=0.01)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1500/1500 [02:55<00:00,  8.55it/s]
# ...
# train finished
# (Actual, Predicted): count
# Counter({(1, 1): 940, (3, 3): 784, (2, 2): 517, (2, 3): 378, (3, 2): 134, (2, 1): 105, (3, 1): 82, (1, 3): 48, (1, 2): 12})

# %% [markdown]
# ### Looking at samples being reweighted

# %%
platform = Reweighting()
platform.setup_data(dataset_name='mnist', classes=[1,7], weights=[0.1,0.9], n_vals_per_class=[5,5], batch_size=20, n_items=20)
platform.setup_model()
# Out:
# ...
# Getting data loader for mnist
# Loading train data
# Gathered 20 train samples
# Gathered 10 validation samples
# Loading test data
# Gathered 2000 test samples
# Data loader initialized
# ...
# Setting up model for dataset mnist
# Model setup finished
# ...

# %%
platform.train(num_iter=500, learning_rate=0.01)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [00:11<00:00, 43.72it/s]
# ...
# train finished
# (Actual, Predicted): count
# Counter({(7, 7): 990, (1, 1): 899, (1, 7): 101, (7, 1): 10})

# %%
platform.train_reweighted(num_iter=500, learning_rate=0.01, show_weights=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [00:24<00:00, 20.17it/s]
# train_reweighted finished
# ...
# (Actual, Predicted): count
# Counter({(1, 1): 973, (7, 7): 916, (7, 1): 84, (1, 7): 27})
