# %%
from model import *
from data_loader import *
from reweighting import *

import matplotlib
matplotlib.rcParams.update({'errorbar.capsize': 5})

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
platform = Reweighting()

# %%
platform.setup_data(dataset_name='cifar', classes=[9,4], weights=[0.95,0.05], batch_size=100)
# Out:
# ...
# Getting data loader for cifar
# Files already downloaded and verified
# Gathered 5000 train samples
# Gathered 10 validation samples
# Files already downloaded and verified
# Gathered 2000 test samples
# Data loader initialized
# ...

# %%
platform.setup_model()
# Out:
# ...
# Setting up model for dataset cifar
# Model setup finished
# ...

# %%
import numpy as np

# %%
a = [[1,2],[3,4]]

# %%
a[:][1]
# Out:
# [3, 4]

# %%
platform.train_reweighted(num_iter=2000, learning_rate=0.001)
# Out:
#  95%|██████████████████████████████████████████████████████████████████████████▏   | 1901/2000 [06:58<00:52,  1.89it/s]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▏   | 1902/2000 [06:58<00:40,  2.39it/s]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▏   | 1903/2000 [06:58<00:32,  2.97it/s]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1904/2000 [06:58<00:27,  3.46it/s]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1905/2000 [06:59<00:24,  3.81it/s]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1906/2000 [06:59<00:22,  4.26it/s]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1907/2000 [06:59<00:19,  4.70it/s]
#
#
#
# ...

# %%
# Evenly distributed data reaches accuracy of around 0.75
platform.train(num_iter=2000, learning_rate=0.001)
# Out:
#  95%|██████████████████████████████████████████████████████████████████████████▏   | 1902/2000 [02:39<00:22,  4.40it/s]
#
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1904/2000 [02:39<00:17,  5.62it/s]
#
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1906/2000 [02:39<00:13,  7.04it/s]
#
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▍   | 1908/2000 [02:39<00:10,  8.54it/s]
#
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▍   | 1910/2000 [02:39<00:09,  9.81it/s]
#
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▌   | 1912/2000 [02:39<00:08, 10.94it/s]
#
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▋   | 1914/2000 [02:40<00:07, 11.95it/s]
#
#
#
#
# ...

# %%
# Data where we have [0.95 0.05] proportion : only have 50% accuracy
platform.train(num_iter=2000, learning_rate=0.001)
# Out:
#  95%|██████████████████████████████████████████████████████████████████████████▏   | 1902/2000 [02:56<00:23,  4.11it/s]
#
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1904/2000 [02:56<00:18,  5.25it/s]
#
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 1906/2000 [02:56<00:14,  6.48it/s]
#
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▍   | 1908/2000 [02:56<00:11,  7.82it/s]
#
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▍   | 1910/2000 [02:56<00:09,  9.07it/s]
#
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▌   | 1912/2000 [02:57<00:08, 10.01it/s]
#
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▋   | 1914/2000 [02:57<00:07, 11.24it/s]
#
#
#
#
# ...
