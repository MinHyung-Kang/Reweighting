# %%
from model import *
from data_loader import *
from reweighting import *

import matplotlib
matplotlib.rcParams.update({'errorbar.capsize': 5})

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
platform = Reweighting(dataset_name='mnist', alpha=0.01, batch_size=100)

# %%
platform.setup_model(classes=[9,4], weights=[0.95,0.05])
# Out:
# Getting data loader
# Gathered 5000 train samples
# Gathered 10 validation samples
# Gathered 1991 test samples

# %%
platform.train_reweighted(num_iter=8000, learning_rate=0.001)
# Out:
#  53%|█████████████████████████████████████████▋                                    | 4277/8000 [13:20<10:54,  5.69it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-61f34eededc7> in <module>
# ----> 1 platform.train_reweighted(num_iter=8000, learning_rate=0.001)
#
# ~\Documents\Stanford\Research\Re\Reweighting\code\pytorch_reweight\reweighting.py in train_reweighted(self, num_iter, learning_rate)
#     127
#     128             # Line 2 get batch of data
# --> 129             X_train, y_train = next(iter(self.data_loader))
#     130             y_train = self.label(y_train)
#     131
#
# C:\Users\Public\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# ...

# %%
platform.train(num_iter=8000, learning_rate=0.001)
# Out:
# ...
#  90%|██████████████████████████████████████████████████████████████████████▏       | 7199/8000 [09:09<00:51, 15.70it/s]
